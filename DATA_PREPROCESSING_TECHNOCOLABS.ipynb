# %%
import pandas as pd

# %%
comp=pd.read_csv('D:\\DOCS\\companies.csv')

# %%
comp.shape#it checks the shape of the raw data.
# Out:
# (196553, 44)

# %%
comp.head()#to check the n number of rows.
# Out:
#         id  Unnamed: 0.1 entity_type  entity_id  parent_id  \
# 0      c:1             0     Company          1        NaN
# 1     c:10             1     Company         10        NaN
# 2    c:100             2     Company        100        NaN
# 3  c:10000             3     Company      10000        NaN
# 4  c:10001             4     Company      10001        NaN
#
#                  name     normalized_name                    permalink  \
# 0            Wetpaint            wetpaint            /company/wetpaint
# 1             Flektor             flektor             /company/flektor
# 2               There               there               /company/there
# 3             MYWEBBO             mywebbo             /company/mywebbo
# 4  THE Movie Streamer  the movie streamer  /company/the-movie-streamer
#
#      category_code     status  ... first_milestone_at last_milestone_at  \
# 0              web  operating  ...         2010-09-05        2013-09-18
# ...

# %%
comp.info()#given the summary about the raw data.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196553 entries, 0 to 196552
# Data columns (total 44 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   196553 non-null  object
#  1   Unnamed: 0.1         196553 non-null  int64
#  2   entity_type          196553 non-null  object
#  3   entity_id            196553 non-null  int64
#  4   parent_id            0 non-null       float64
#  5   name                 196531 non-null  object
#  6   normalized_name      196527 non-null  object
#  7   permalink            196553 non-null  object
#  8   category_code        123186 non-null  object
#  9   status               196553 non-null  object
#  10  founded_at           91227 non-null   object
#  11  closed_at            2620 non-null    object
#  12  domain               126545 non-null  object
#  13  homepage_url         126545 non-null  object
#  14  twitter_username     80591 non-null   object
# ...

# %%
comp.duplicated().sum()#checks the duplicate values in raw data
# Out:
# 0

# %%
comp.isnull().sum()# to check the total null values in any columns.
# Out:
# id                          0
# Unnamed: 0.1                0
# entity_type                 0
# entity_id                   0
# parent_id              196553
# name                       22
# normalized_name            26
# permalink                   0
# category_code           73367
# status                      0
# founded_at             105326
# closed_at              193933
# domain                  70008
# homepage_url            70008
# twitter_username       115962
# logo_url                86443
# logo_width              86443
# logo_height             86443
# short_description      189422
# description            104505
# overview                69582
# tag_list               115101
# country_code           108563
# state_code             145650
# city                   112663
# region                      0
# first_investment_at    193970
# last_investment_at     193970
# investment_rounds      193962
# invested_companies     193962
# first_funding_at       165046
# ...

# %%
comp[comp.isnull().any(axis=1)]#here we check that what values are there in those columns.
# Out:
#              id  Unnamed: 0.1 entity_type  entity_id  parent_id  \
# 0           c:1             0     Company          1        NaN
# 1          c:10             1     Company         10        NaN
# 2         c:100             2     Company        100        NaN
# 3       c:10000             3     Company      10000        NaN
# 4       c:10001             4     Company      10001        NaN
# ...         ...           ...         ...        ...        ...
# 196548  c:99940        196548     Company      99940        NaN
# 196549   c:9995        196549     Company       9995        NaN
# 196550   c:9996        196550     Company       9996        NaN
# 196551   c:9997        196551     Company       9997        NaN
# 196552   c:9998        196552     Company       9998        NaN
#
#                       name     normalized_name                    permalink  \
# 0                 Wetpaint            wetpaint            /company/wetpaint
# ...

# %%
comp.dtypes#shows which columns are of which raw data type.
# Out:
# id                      object
# Unnamed: 0.1             int64
# entity_type             object
# entity_id                int64
# parent_id              float64
# name                    object
# normalized_name         object
# permalink               object
# category_code           object
# status                  object
# founded_at              object
# closed_at               object
# domain                  object
# homepage_url            object
# twitter_username        object
# logo_url                object
# logo_width             float64
# logo_height            float64
# short_description       object
# description             object
# overview                object
# tag_list                object
# country_code            object
# state_code              object
# city                    object
# region                  object
# first_investment_at     object
# last_investment_at      object
# investment_rounds      float64
# invested_companies     float64
# ...

# %%
comp.corr()#to check the dependencies between each other.
# Out:
#                     Unnamed: 0.1  entity_id  parent_id  logo_width  \
# Unnamed: 0.1            1.000000  -0.269074        NaN   -0.050397
# entity_id              -0.269074   1.000000        NaN    0.073013
# parent_id                    NaN        NaN        NaN         NaN
# logo_width             -0.050397   0.073013        NaN    1.000000
# logo_height            -0.065973   0.127747        NaN    0.784554
# investment_rounds       0.018964  -0.079022        NaN    0.043238
# invested_companies      0.019659  -0.073513        NaN    0.045034
# funding_rounds          0.019632  -0.256673        NaN    0.002109
# funding_total_usd       0.014612  -0.113679        NaN   -0.029624
# milestones              0.090653  -0.370364        NaN   -0.013658
# relationships           0.030060  -0.158604        NaN   -0.010923
# lat                     0.022726  -0.045110        NaN    0.003374
# lng                    -0.030353   0.068573        NaN    0.016735
# ...

# %%
comp.drop(columns=['parent_id','first_investment_at','last_investment_at','investment_rounds','invested_companies'],inplace=True)

# %%
comp.drop(columns=['closed_at','short_description','founded_at','state_code','first_funding_at','last_funding_at','funding_rounds','funding_total_usd','lat','lng','ROI'],inplace=True)

# %%
comp
# Out:
#              id  Unnamed: 0.1 entity_type  entity_id                name  \
# 0           c:1             0     Company          1            Wetpaint
# 1          c:10             1     Company         10             Flektor
# 2         c:100             2     Company        100               There
# 3       c:10000             3     Company      10000             MYWEBBO
# 4       c:10001             4     Company      10001  THE Movie Streamer
# ...         ...           ...         ...        ...                 ...
# 196548  c:99940        196548     Company      99940           Webgility
# 196549   c:9995        196549     Company       9995              FohBoh
# 196550   c:9996        196550     Company       9996                 CSC
# 196551   c:9997        196551     Company       9997       Top-candidate
# 196552   c:9998        196552     Company       9998      Closet Couture
#
#            normalized_name                    permalink     category_code  \
# ...

# %%
comp.describe()# it returns the basic statistical details of the data frame.
# Out:
#         Unnamed: 0.1      entity_id     logo_width    logo_height  \
# count  196553.000000  196553.000000  110110.000000  110110.000000
# mean    98276.000000  153006.227333     459.132685     222.728917
# std     56740.108067   90209.250941     594.982577     333.090722
# min         0.000000       1.000000       1.000000       1.000000
# 25%     49138.000000   59850.000000     192.000000      70.000000
# 50%     98276.000000  174539.000000     267.000000     105.000000
# 75%    147414.000000  232655.000000     484.000000     232.000000
# max    196552.000000  286215.000000   18200.000000    9600.000000
#
#          milestones  relationships
# count  91699.000000  129667.000000
# mean       1.199402       2.852067
# std        0.540099       9.100309
# min        1.000000       1.000000
# 25%        1.000000       1.000000
# 50%        1.000000       1.000000
# 75%        1.000000       3.000000
# max        9.000000    1189.000000

# %%
comp.describe().sum()#returns the sum of value of requested dataframe.
# Out:
# Unnamed: 0.1     8.429491e+05
# entity_id        1.193028e+06
# logo_width       1.303081e+05
# logo_height      1.206738e+05
# milestones       9.171374e+04
# relationships    1.308740e+05
# dtype: float64
